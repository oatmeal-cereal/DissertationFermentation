# %%
import spacy
from spacy import displacy
import json
import os
import pyobo
from scispacy.linking import EntityLinker
from scispacy.abbreviation import AbbreviationDetector
import pyab3p
#from scispacy.umls_linking import UmlsEntityLinker
#%pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bionlp13cg_md-0.5.4.tar.gz
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz

path_to_model = os.path.normpath('C:\\Users\\jace\\Documents\\assignments\\dissertation DLC content\\en_ner_bionlp13cg_md-0.5.4\\en_ner_bionlp13cg_md\\en_ner_bionlp13cg_md-0.5.4')
path_to_model2 = '..\\..\\dissertation DLC content\\en_ner_bc5cdr_md-0.5.4\\en_ner_bc5cdr_md\\en_ner_bc5cdr_md-0.5.4'
path_to_model3 = 'en_core_sci_sm'

# %%
model = spacy.load(path_to_model3)

#linker = model.add_pipe('scispacy_linker', config={'resolve_abbreviations': True, 'linker_name': 'rxnorm'})

abbrev = model.add_pipe('abbreviation_detector', last=True, config={'make_serializable': True})
# Out:
# c:\Users\jace\miniconda3\envs\scispacy\lib\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
""" with open('..\\list_files\\annotations_all_sentences.json', 'r', encoding='utf-8') as f:
    testing_data = json.load(f)['annotations'] """
    
with open('..\\..\\dissertation\\list_files\\abbreviations_examples.txt', 'r', encoding='utf-8') as f:
    sentences = f.readlines()

# %%
for i, line in enumerate(sentences):
    print(line)
    doc = model(line)
    #ents_and_labels = [{'label': ent.label_, 'text': linker.kb.cui_to_entity[ent.text].canonical_name, 'start': ent.start, 'end': ent.end} for ent in doc.ents if ent.label_ == 'SIMPLE_CHEMICAL']
    #print(ents_and_labels)

    if doc._.abbreviations:
        print(i)
        displacy.render(doc, style="ent", jupyter=True, minify=True)
        
        for abr in doc._.abbreviations:
            print(abr)

    """ linker_labels = []
    for ent in doc.ents:
        #print([linker.kb.cui_to_entity[lent[0]] for lent in ent._.kb_ents])
        if ent._.kb_ents and ent.label_ == 'CHEMICAL':
            #print(ent._.kb_ents[0])
            label = linker.kb.cui_to_entity[ent._.kb_ents[0][0]]
            linker_labels.append(label.canonical_name)
            print(label.aliases) """
    
    #print(linker_labels)
    print()

    """ with open('..\\list_files\\ner_triples.jsonl', 'a', encoding='utf-8') as f:
        json.dump((text, ents_and_labels), f)
        f.write('\n') """
    i += 1
# Out:
# Saccharomyces fragilis, also known as S. fragilis, produces galactosidase
#
#
# Saccharomyces fragilis (S. fragilis) produces galactosidase. The microbe S. cerevisiae is in the same genus as S. fragilis.
#
# 1
# c:\Users\jace\miniconda3\envs\scispacy\lib\site-packages\scispacy\abbreviation.py:248: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)
# ...
