# %%
from transformers import AutoTokenizer as autok
from transformers import BertForTokenClassification as bert
#from transformers import BertForSequenceClassification as bert
from transformers import AutoModel as autom
from transformers import pipeline
from transformers import AutoConfig
import os
import json
from pypdf import PdfReader as pr
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import AutoTokenizer as autok
#       2 from transformers import BertForTokenClassification as bert
#       3 #from transformers import BertForSequenceClassification as bert
#
# File c:\Users\jace\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
# ...

# %%
biobert = 'dmis-lab/biobert-v1.1'
llmner = 'timo-10000/LLM-NER'
chatglm = 'zai-org/chatglm3-6b'
scibert = 'allenai/scibert_scivocab_uncased'
lora = 'lopohui/lora-chatglm'

tokenizer = autok.from_pretrained(llmner)

model = bert.from_pretrained(llmner, trust_remote_code=True)

# %%
nlp = pipeline('token-classification', model=model, tokenizer=tokenizer, aggregation_strategy='first')

for file in os.listdir(os.getcwd() + "\\fermentation_papers")[:5]:
    filename = os.fsdecode(file)
    if filename.endswith('json'):
        with open(f"{os.getcwd()}\\fermentation_papers\\{filename}", 'r', encoding='utf-16') as f:
            text = json.load(f)
    elif filename.endswith('pdf'):
        path = Path(os.getcwd() + "\\fermentation_papers\\" + filename)
        reader = pr(path)
        text = ""
        for page in reader.pages:
            text = text + page.extract_text()
    doc = model(text)
    ents_and_labels = [(ent.label_, ent.text) for ent in doc.ents]
    print(ents_and_labels)
