# %%
from pypdf import PdfReader as pr
import scispacy
import spacy
from spacy import displacy
#from scispacy.abbreviation import AbbreviationDetector
import os
import pprint
from pathlib import Path

model = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pypdf import PdfReader as pr
# ----> 2 import scispacy
#       3 import spacy
#       4 from spacy import displacy
#
# ModuleNotFoundError: No module named 'scispacy'

# %%
training_data = [{
    "id": 0,
    "sentences": [
        ("The microbial consortium between Pediococcus acidilactici and Acetobacter cerevisiae enabled the metabolization of all the xylose contained in the liquor", 
        [(33, 57, "Microbe"), (62, 84, "Microbe"), (97, 111, "Consumes"), (123, 129, "Substrate")]),
        ("The rest of the sugars were released into the liquor (g per 100 g of the corresponding sugar in the RH): 57.1%% xylose, 7.3%% galactose, 8.6%% arabinose and 2.5%% mannose (calculated data).",
        [(111, 118, "Substrate"), (124, 124, "Substrate"), (140, 149, "Substrate"), (159, 166, "Substrate")]),
        ("Some wild-type strains have a strong tolerance for lignocellulose-derived inhibitors, e.g. lactic acid-producing bacteria, Lactobacillus plantarum, have the ability to ferment in the presence of 8.0 g L^−1 furfural and 6.0 g L%−1 5-hydroxymethylfurfural (5-HMF)",
        [(37, 46, "Thrives in"), (51, 84, "Condition"), (91, 102, "Metabolite"), (123, 147, "Microbe"), (103, 112, "Produces"), (157, 175, "Thrives in"), (195, 213, "Condition"), (218, 259, "Condition")]),
        ("Since A. cerevisiae is also a producer of acetic acid",
        [(6, 19, "Microbe"), (30, 38, "Produces"), (42, 53, "Metabolite")]),
        ("the fermentation processes presented here also demonstrated the ability of P. acidilactici and A. cerevisiae, and co-cultivation, to consume different sugars",
        [(75, 90, "Microbe"), (95, 109, "Microbe"), (114, 129, "Cocultures with")]),
        ("it can be seen that both P. acidilactici and A. cerevisiae were able to metabolize 5-HMF and furfural",
        [(25, 40, "Microbe"), (45, 58, "Microbe"), (72, 82, "Consumes"), (83, 88, "Substrate"), (93, 101, "Substrate")]),
        ("the temperature of the cultivation was started at 37 °C and, 24 h later, changed to 30 °C",
        [(39, 46, "Thrives in"), (50, 55, "Condition"), (84, 89, "Condition")]),
        ("The stirring speeds and blades employed also varied according to the fractions used (200 rpm when using only the detoxified liquor, and 600 rpm when using only the WIS or the blend of both fractions)",
        [(85, 92, "Condition"), (136, 143, "Condition")])
    ]},
    {id: 1,
     "sentences": [
        ("Broad bean paste is usually made by the following three phases: a natural fermentation of chili-to-moromi, a conversion from broad bean to koji by Aspergillus oryzae",
         [(0, 16, "Product"), (109, 119, "Consumes"), (125, 135, "Substrate"), (136, 138, "Produces"), (147, 165, "Microbe")])
     ]},
    {id: 2,
     "sentences": [
         ("The cellulose-rich biomass was holistically exposed to enzymatic hydrolysis (Cellulase CTEC 21) and inoculated with Clostridium acetobutylicum (11,274) to facilitate biobutanol production",
          [(4, 13, "Substrate"), (116, 142, "Microbe"), (166, 176, "Metabolite")]),
         ("butanol is produced from various lignocellulose-rich bio- mass residues by fermentation of Acetone Butanol Ethanol (ABE)",
          [(0, 7, "Metabolite"), (11, 19, "Produces"), (91, 120, "Substrate")]),
         ("The sterile media was then inoculated with 10% (v/v) of overnight grown RCM culture (Clostridium acetobutylicum) and incubated under anaerobic conditions for 24 h",
          [(85, 111, "Microbe"), (117, 126, "Thrives in"), (133, 153, "Condition")]),
         ("The optimal conditions for effective butanol production (0.33 g L −1 h −1 ) were found to occur with the optimal interval of the influential parameters (incubation time of 122.5 h, biomass feed of 24.5 mg/L, and inoculum size of 9.75%)",
          [(4, 22, "Thrives in"), (37, 44, "Metabolite"), (45, 55, "Produces"), (181, 207, "Condition"), (212, 234, "Condition")]),
         ("the acidity is the key factor in the lignin-removal which helps to recover a significant amount of reducing sugars from the cellulose-rich material",
          [(4, 11, "Condition"), (19, 29, "Thrives in"), (99, 107, "Consumes"), (108, 114, "Substrate")])
     ]},
    {id: 3,
     "sentences": [
         ("glucose is found to be a significant component in FW, and yeast could convert glucose into ethanol under anaerobic conditions in a controlled environment",
          [(0, 7, "Substrate"), (58, 63, "Microbe"), (91, 98, "Metabolite"), (64, 69, "Thrives in"), (70, 77, "Consumes"), (78, 85, "Substrate"), (86, 90, "Produces"), (105, 125, "Condition")]),
         ("Anaerobic fermentation without enzymatic assistance by Saccharomyces cerevisiae with temperature 30 °C was modeled in all scenarios",
          [(0, 22, "Condition"), (55, 79, "Microbe"), (85, 102, "Condition")])
     ]},
    {id: 4,
     "sentences": [
         ("Exploitation of soil bacteria for production of ferulic acid (FA)",
          [(16, 29, "Microbe"), (34, 44, "Produces"), (48, 65, "Metabolite")]),
         ("the maximum FA yield of 394.76 mg/kg was achieved using co-culture of Bacillus sp. MB2, Bacillus sp. WB8A and B. pumilus strain WB1A, which was 2.5-fold higher than FA produced by single culture",
          [(12, 14, "Metabolite"), (15, 20, "Produces"), (56, 66, "Cocultures with"), (70, 86, "Microbe"), (88, 105, "Microbe"), (110, 132, "Microbe"), (168, 176, "Produces")]),
         ("In this study, banana stem waste is used as substrate for FA production",
          [(15, 26, "Substrate"), (36, 40, "Consumes"), (58, 60, "Metabolite"), (61, 71, "Produces")]),
         ("FA production in the range of 0.2–1.8 μg/mL on chopped wheat straw, corn stalk, rice straw, Chinese wildrye and medicago sativa using co-cultures of Piromyces and Methanobrevibacter ruminantium",
          [(0, 2, "Metabolite"), (3, 13, "Produces"), (47, 66, "Substrate"), (68, 78, "Substrate"), (80, 90, "Substrate"), (92, 107, "Substrate"), (112, 127, "Substrate"), (128, 133, "Consumes"), (134, 145, "Cocultures with"), (149, 158, "Microbe"), (163, 193, "Microbe")]),
         ("FA production from rice bran was four times greater than Aspergillus oryzae through fermentation of A. oryzae and Rhizopus oryzae co-culture.",
          [(0, 2, "Metabolite"), (3, 13, "Produces"), (19, 28, "Substrate"), (57, 75, "Microbe")]),
         ("The flask was closed using cotton plug and incubated for 24 h at 35 °C and 150 rpm using incubator shaker",
          [(43, 52, "Thrives in"), (65, 70, "Condition"), (75, 82, "Condition")]),
         ("The results of 11 types of substrate including d-cellobiose, α-d-glucose, d-mannose, d-fructose, d-galactose, d-fucose, l-fucose, l-rhamnose, pectin, d-galacturonic acid and d-glucuronic acid were selected for further evaluation since the profiles could represent hydrolytic activity of lignocellulosic biomass during fermentation process",
          [(47, 59, "Substrate"), (61, 72, "Substrate"), (74, 83, "Substrate"), (85, 95, "Substrate"), (97, 108, "Substrate"), (110, 118, "Substrate"), (120, 128, "Substrate"), (130, 140, "Substrate"), (142, 148, "Substrate"), (150, 169, "Substrate"), (174, 191, "Substrate"), (264, 283, "Consumes")]),
         ("Feruloyl esterase or ferulic acid esterase (FAE) is known as the most important enzyme to cleave the feruloyl-polysaccharide",
          [(0, 48, "Enzyme")]),
         ("FAEs take a wide range of temperature and pH stabilities, with more than 60% of optimal activities between temperature of 25 and 50 °C and between pH 5.0 and 7.5",
          [(0, 4, "Enzyme"), (80, 98, "Thrives in"), (99, 134, "Condition"), (139, 161, "Condition")])
     ]},
    {id: 5,
     "sentences": [
         ("lactic acid fermentation was performed with optimal OB hydrolysate by Lactobacillus delbrueckii subsp. bulgaricus OZZ4 and Lactobacillus plantarum OZH8",
          [(0, 11, "Metabolite"), (67, 69, "Produces"), (70, 118, "Microbe"), (123, 151, "Microbe")]),
         ("Strains of lactic acid bacteria (LAB); Lactobacillus delbrueckii subsp. bulgaricus OZZ4 and Lactobacillus plantarum OZH8",
          [(11, 37, "Group of microbes"), (39, 87, "Microbe"), (92, 120, "Microbe")])
     ]},
    {id: 6,
     "sentences": [
         ("The feedstocks to produce ascorbic acid include corn, wheat, molasses and d-sorbitol",
          [(26, 39, "Metabolite"), ("48, 52", "Substrate"), (54, 59, "Substrate"), (61, 69, "Substrate"), (74, 84, "Substrate")]),
         ("Ascorbic acid is produced from d-sorbitol, a sugar alcohol that can be obtained from various feedstock such as corn, cassava and wheat",
          [(0, 13, "Metabolite"), (17, 25, "Produces"), (11, 115, "Substrate"), (117, 124, "Substrate"), (129, 134, "Substrate")]),
         ("first fermenter (FR-101) along with ammonia, water and air to undergo oxidative fermentation under 30 °C and pH 6 with an initial concentration of 200 g/L [11]. In the first fermenter, the sorbitol is converted to sorbose by Gluconobacter oxydans",
          [(36, 113, "Condition"), (122, 154, "Produces"), (189, 197, "Substrate"), (201, 210, "Consumes"), (211, 213, "Produces"), (214, 221, "Metabolite"), (225, 246, "Microbe")]),
         ("Pseudoglyconobacter Saccharoketogenes for 72 h to produce sodium keto-gluconic acid [13]. In this fermenter, the conversion of sorbose to sodium keto-gluconic acid",
          [(0, 37, "Microbe"), (50, 57, "Produces"), (58, 83, "Metabolite"), (113, 123, "Consumes"), (127, 134, "Substrate"), (135, 137, "Produces"), (138, 163, "Metabolite")])
     ]},
    {id: 7,
     "sentences": [
         ("The observation that lignosulphonic acids inhibit the fermentation of sucrose, glucose and invert sugar with Candida utilis",
          [(21, 41, "Condition"), ("42, 49", "Inhibits"), (70, 77, "Substrate"), (79, 86, "Substrate"), (91, 103, "Substrate"), (109, 123, "Microbe")]),
         ("Saccharomyces cerevisiae ferments mainly hexoses",
          [(0, 24, "Microbe"), (41, 48, "Substrate")]),
         ("invertase produced by Candida utilis for degrading the disaccharide to glucose and fructose",
          [(0, 9, "Enzyme"), (10, 21, "Sources"), (22, 36, "Microbe"), (41, 50, "Consumes"), (55, 67, "Substrate"), (71, 78, "Metabolite"), (83, 91, "Metabolite")])
     ]},
    {id: 8,
     "sentences": [
         ("Soybeans as a food is used as soymilk, soy flour, soy oil, feed for livestock and poultry, soy concentrate, protein isolates, soy yoghurt, tofu and fermented foods such as Tempeh, soy sauce, Miso, Natto and Sufu",
          [(0, 8, "Substrate"), (130, 137, "Product"), (172, 178, "Product"), (180, 189, "Product"), (191, 195, "Product"), (197, 202, "Product"), (207, 211, "Product")]),
         ("B. subtilis fermented soybeans foods in various parts of the world. One of the common examples is Kinema",
          [(0, 11, "Microbe"), (22, 30, "Substrate"), (98, 104, "Product")]),
         ("fermented soy foods reported in literature are: Natto in Japan, Thua-Nao in Thailand, Douchi in China, Chung-kook-jong in Korea, Tao-siin Philippines, Dawadawa in Africa",
          [(48, 53, "Product"), (64, 72, "Product"), (86, 92, "Product"), (103, 118, "Product"), (129, 137, "Product"), (151, 159, "Product")]),
         ("Bacillus spp. is the most dominant naturally fermenting agents in soybeans. These hydrolytic bacteria are associated with utilization and reduction of indigestible oligosaccharides and polysaccharides",
          [(0, 13, "Microbe"), (82, 101, "Microbe"), (164, 180, "Substrate"), (185, 200, "Substrate")]),
         ("B. subtilis is a group of related strains under the family Bacillaceae",
          [(0, 11, "Group of Microbes"), (59, 70, "Family of Microbes")]),
         ("These traditionally fermented soyfoods are littered with several other microbial species such as Enterococcus faecium, Candia parapsilosis, Geotrichum candidum etc.",
          [(97, 117, "Microbe"), (119, 138, "Microbe"), (140, 159, "Microbe")]),
         ("soaked beans were autoclaved at 121°C for 35 min, cooled to 30 to 35°C, inoculate with pure culture, ferment at 37°C for 48 hours at 85% RH",
          [(18, 28, "Thrives in"), (32, 37, "Condition"), (60, 70, "Condition"), (72, 81, "Thrives in"), (112, 116, "Condition"), (133, 139, "Condition")]),
         ("prepared Thua-Nao using pure culture of B. subtilis",
          [(9, 17, "Product"), (40, 51, "Microbe")]),
         ("B. subtilis during Thua Nao fermentation releases proteinases that play important role in proteolysis of soy proteins",
          [(0, 11, "Microbe"), (19, 27, "Product"), (41, 49, "Sources"), (50, 61, "Enzyme"), (105, 117, "Substrate")]),
         ("B. subtilis fermentation tends to increase total polyphenolic compound and anthocyanins, upto 10 and 250%, respectively during Natto fermentation of black soybeans",
          [(0, 11, "Microbe"), (34, 42, "Produces"), (49, 70, "Metabolite"), (75, 88, "Metabolite"), (127, 132, "Product"), (149, 163, "Substrate")]),
         ("Fermentation of soybeans, particularly with B. subtilis, lead to extensive hydrolysis of all the macromolecules such as proteins to smaller peptides, amino acids and simple sulphur and nitrogen compounds; starch into oligosaccharides and simple sugars and lipids into simple fatty acids",
          [(44, 56, "Microbe"), (75, 85, "Consumes"), (120, 128, "Substrate"), (129, 131, "Produces"), (132, 149, "Metabolite"), (150, 161, "Metabolite"), (166, 180, "Metabolite"), (185, 204, "Metabolite"), (205, 211, "Substrate"), (212, 216, "Produces"), (217, 233, "Metabolite"), (238, 251, "Metabolite"), (256, 262, "Substrate"), (263, 267, "Produces"), (275, 286, "Metabolite")]),
         ("fermented soybeans inhibits adhesion of ETEC K88 in Rhizopus fermented soybeans",
          [(0, 18, "Product"), (19, 27, "Inhibits"), (40, 48, "Microbe"), (52, 60, "Microbe")])
     ]},
    {id: 9,
     "sentences": [
         ("Finger millet (brown variety) was collected from local market of Dharan. Fermentation starter was prepared using yeast (Saccharomyces cerevisiae) and mold (Rhizopus oryzae)",
          [(0, 29, "Substrate"), (113, 145, "Microbe"), (150, 172, "Microbe")]),
         ("Yeast was grown in molasses broth of 6ºBx TSS for 3 days at 27 ºC",
          [(0, 5, "Microbe"), (10, 15, "Thrives in"), (19, 65, "Condition")]),
         ("Mold bran was prepared by inoculating isolated mold in sterile wheat bran, incubating for 5 days at 30 ºC",
          [(0, 4, "Microbe"), (26, 37, "Thrives in"), (75, 85, "Thrives in"), (100, 105, "Condition")]),
         ("Defined fermentation starter (prepared from rice using pure cultures of S. cerevisiae and R. oryzae) was mixed to the cooked millet at the rate of 1% (m/m), and kept for 2 days at 30ºC for bio-mass development (aerobic fermentation)",
          [(72, 85, "Microbe"), (90, 99, "Microbe"), (180, 184, "Condition"), (211, 231, "Condition")]),
         ("similar alcohol content (6.68% v/v) in millet Jand fermented by using starter made from Rhizopus and Saccharomyces spp",
          [(0, 35, "Condition"), (39, 50, "Product"), (88, 96, "Microbe"), (101, 118, "Microbe")]),
         ("semisolid state fermentation on glucose in taro fermentation using starter containing R. tankinensis, R. oryzae, R. chinensis and S. cerevisiae, but contrary to our finding, they reported a significantly higher yield of alcohol in semisolid fermentation than that of solid state fermentation",
          [(0, 15, "Condition"), (32, 39, "Substrate"), (67, 85, "Cocultures with"), (86, 100, "Microbe"), (102, 111, "Microbe"), (130, 143, "Microbe"), (211, 216, "Produces"), (220, 227, "Metabolite"), (231, 240, "Condition"), (267, 278, "Condition")]),
         ("Semi-solid state fermentations unacceptably increased the acidity resulting in substantial lowering in the taste, color and smell preference of the millet beer",
          [(0, 16, "Condition"), (58, 65, "Condition"), (148, 159, "Product")])
     ]},
    {id: 10,
     "sentences": [
         ("Whey proteins hydrolysis occurred at all incubation temperatures evaluated (32–50 ◦C), with the major proteolytic effect within the range of 35–42 ◦C",
          [(0, 13, "Substrate"), (75, 84, "Condition"), (96, 101, "Thrives in"), (141, 149, "Condition")]),
         ("Naturally fermented acid whey (NFAW) is obtained by the fermentation of whey",
          [(0, 36, "Product"), (40, 51, "Creates"), (72, 76, "Substrate")]),
         ("Spontaneous whey fermentation mostly depends on lactic acid bacteria (LAB), which convert lactose (the major component of whey) into lactic acid",
          [(48, 74, "Group of Microbes"), (82, 89, "Consume"), (90, 97, "Substrate"), (128, 132, "Produces"), (133, 144, "Metabolite")]),
         ("Whey from queso fresco production was used in this study and had a pH close to neutral (6.49–6.56), which is characteristic of a sweet whey (pH > 6.0)",
          [(0, 4, "Substrate"), (67, 99, "Condition"), (129, 134, "Flavour")]),
         ("convert lactose into value-added chemicals such as lactic acid and other compounds, including ethanol, citric, acetic, lactulose, etc.",
          [(0, 7, "Consumes"), (8, 15, "Substrate"), (16, 20, "Produces"), (51, 62, "Metabolite"), (94, 101, "Metabolite"), (103, 109, "Metabolite"), (111, 117, "Metabolite"), (119, 128, "Metabolite")]),
         ("genuses such as Lactococcus, Lactobacillus, and Streptococcus are commonly present and have been associated with lactic acid fermentation",
          [(16, 27, "Genus of Microbes"), (29, 42, "Genus of Microbes"), (48, 61, "Genus of Microbes"), (113, 124, "Metabolite"), (125, 137, "Produces")]),
         ("temperature had a significant effect on the lactic acid production, where the highest values were observed at the temperature range of 37–42 ◦C",
          [(44, 55, "Metabolite"), (56, 67, "Produces"), (78, 92, "Thrives in"), (135, 143, "Conditions")]),
         ("At higher temperatures (45–50 ◦C), lactic acid production was lower (3–5 g/L) and no significant increase (p < 0.05) was observed after 24 h, indicating that spontaneous whey fermentation was affected by the high temperature",
          [(24, 32, "Condition"), (35, 46, "Metabolite"), (62, 67, "Doesn't thrive in"), (208, 224, "Condition")]),
         ("lactic acid production of 5.3g/L after 48h at 37 ◦C using Lactobactillus bulgaricus for whey fermentation",
          [(0, 11, "Metabolite"), (12, 22, "Produces"), (58, 72, "Microbe"), (88, 92, "Substrate")]),
         ("L. acidophilus, L. bulgaricus, and L. casei presented more proteolytic activity than Str. thermophilus and Lb. paracasei",
          [(0, 15, "Microbe"), (16, 29, "Microbe"), (35, 43, "Microbe"), (85, 102, "Microbe"), (107, 120, "Microbe")])
     ]},
    {id: 11,
     "sentences": [
         ("LAB, including the genera Lactobacillus, Lactococcus, Leuconostoc, Enterococcus, Streptococcus and Pediococcus",
          [(0, 3, "Group of Microbes"), (26, 39, "Genus of Microbes"), (41, 52, "Genus of Microbes"), (54, 65, "Genus of Microbes"), (67, 79, "Genus of Microbes"), (81, 94, "Genus of Microbes"), (99, 110, "Genus of Microbes")]),
         ("In dairy fermentations, strains of LAB produce metabolites such as acetic, lactic, propionic, phenyllactic and hydroxyphenyl lactic acids",
          [(35, 38, "Groups of Microbes"), (39, 46, "Produce"), (67, 74, "Metabolite"), (75, 81, "Metabolite"), (83, 92, "Metabolite"), (94, 106, "Metabolite"), (125, 137, "Metabolite")]),
         ("reuterin produced by Limosilactobacillus reuteri is reported as a potent compound with broad-range antimicrobial activity that inhibits fungi but also Gram-negative bacteria",
          [(0, 8, "Metabolite"), (21, 48, "Microbe"), (127, 135, "Inhibits"), (136, 141, "Group of Microbes"), (151, 173, "Group of Microbes")]),
         ("Limosilactobacillus reuteri uses a CoA-dependent pathway, in which 3-hydroxypropionaldehyde (3-HPA, the active antimicrobial system) is obtained from glycerol in a reaction catalysed by the coenzyme B12-dependent glycerol/diol dehydratase",
          [(0, 27, "Microbe"), (67, 91, "Metabolite"), (93, 98, "Metabolite"), (150, 158, "Substrate"), (173, 182, "Sources"), (199, 238, "Enzyme")]),
         ("pediocins produced by Pediococcus spp.",
          [(0, 9, "Metabolite"), (10, 18, "Produces"), (22, 38, "Microbe")]),
         ("Helveticin-M, produced by Lactobacillus crispatus",
          [(0, 13, "Metabolite"), (14, 22, "Produces"), (26, 49, "Microbe")]),
         ("Nisin, lacticin 3147 and 481, pediocin AcH, thermophilin, macedocin, reuterin and enterocin AS-38 and KP",
          [(0, 5, "Metabolite"), (7, 20, "Metabolite"), (30, 42, "Metabolite"), (44, 56, "Metabolite"), (58, 67, "Metabolite"), (69, 77, "Metabolite"), (82, 97, "Metabolite"), (102, 104, "Metabolite")]),
         ("Lactococcus lactis and Lactiplantibacillus plantarum strains were studied in model cheeses against Listeria monocytogenes",
          [(0, 18, "Microbe"), (23, 52, "Microbe"), (83, 90, "Product"), (91, 98, "Inhibits"), (99, 121, "Microbe")]),
         ("Staph. equorum inhibited the growth of L. monocytogenes",
          [(0, 14, "Microbe"), (15, 24, "Inhibits"), (39, 55, "Microbe")]),
         ("C. crustorum, Lpb. plantarum and Lmb. fermentum decreased the levels of L. monocytogenes in cheese",
          [(0, 12, "Microbe"), (14, 28, "Microbe"), (33, 47, "Microbe"), (48, 57, "Inhibits"), (72, 88, "Microbe"), (92, 98, "Product")]),
         ("E. faecium KE82 is suggested as a protective culture, but the indigenous bacteriocin-producing LAB might contribute to the inhibition of L. monocytogenes in Graviera",
          [(0, 10, "Microbe"), (123, 133, "Inhibits"), (137, 153, "Microbe"), (157, 165, "Product")]),
         ("Pecorino Sardo PDO Lpb. plantarum (commercial) and an autochthonous LAB (Lb. delbruekii ssp. sunkii). Protection against L. monocytogenes Lb. delbruekii ssp. sunkii was as effective as the commercial culture for the protection against L. monocytogenes",
          [(0, 18, "Product"), (19, 46, "Microbe"), (73, 99, "Microbe"), (102, 120, "Inhibits"), (121, 137, "Microbe"), (138, 164, "Microbe"), (216, 234, "Inhibits"), (235, 251, "Microbe")]),
         ("Lcb. paracasei delayed the growth of Staph. aureus and L. monocytogenes in Coalho cheese",
          [(0, 14, "Microbe"), (15, 33, "Inhibits"), (37, 50, "Microbe"), (55, 71, "Microbe"), (75, 88, "Product")]),
         ("E. faecium CRL1879 ensured an efficient control of L. monocytogenes for up to 30 days without altering the organoleptic properties of the artisanal cheese",
          [(0, 18, "Microbe"), (30, 50, "Inhibits"), (51, 67, "Microbe"), (138, 154, "Product")])
     ]},
    {id: 12, 
     "sentences": [
         ("milk with a 10% yogurt starter containing Lactobacillus delbrueckii subsp. bulgaricus and Streptococcus thermophilus, also various S. cerevisiae concentrations",
          [(0, 4, "Substrate"), (23, 41, "Cocultures with"), (42, 85, "Microbe"), (90, 116, "Microbe"), (131, 144, "Microbe")]),
         ("The inoculated milk was fermented at 30 ºC",
          [(15, 19, "Substrate"), (37, 42, "Condition")]),
         ("ethanol production by S. cerevisiae",
          [(0, 7, "Metabolite"), (8, 18, "Produces"), (22, 35, "Microbe")]),
         ("S. cerevisiae addition was also found to slightly inhibit the growth of L. delbrueckii subsp. bulgaricus and S. thermophilus",
          [(0, 13, "Microbe"), (50, 57, "Inhibits"), (72, 104, "Microbe"), (109, 124, "Microbe")]),
         ("the optimum fermentation is conducted at 42 ºC using fresh (raw or pasteurized) milk because it is considered the standard for making high-quality yogurt",
          [(4, 11, "Thrives in"), (41, 46, "Condition"), (53, 84, "Substrate"), (147, 153, "Product")]),
         ("If the optimum fermentation conditions are met, the milk will be transformed into yogurt with a soft-thick texture and a tangy flavor due to the production of lactic acid",
          [(7, 38, "Thrives in"), (52, 56, "Substrate"), (82, 88, "Product"), (121, 133, "Flavour"), (145, 155, "Produces"), (159, 170, "Metabolite")]),
         ("Saccharomyces cerevisiae, a well-known yeast strain known for its health benefits, fermentative metabolism, and ethanol production capabilities, to enhance yogurt quality",
          [(0, 51, "Microbe"), (112, 119, "Metabolite"), (120, 144, "Produces"), (156, 162, "Product")]),
         ("it has been shown that S. cerevisiae could grow in milk and produce small amounts of ethanol, glycerol, and lactic acid",
          [(23, 36, "Microbe"), (43, 47, "Thrives in"), (51, 55, "Substrate"), (60, 67, "Produces"), (85, 92, "Metabolite"), (94, 102, "Metabolite"), (108, 119, "Metabolite")]),
         ("While milk itself is not a suitable growth medium for S. cerevisiae due to limitations like the inability to ferment milk’s lactose",
          [(6, 10, "Substrate"), (21, 35, "Doesn't thrive in"), (54, 67, "Microbe"), (96, 116, "Doesn't consume") (124, 131, "Substrate")]),
         ("L. delbrueckii subsp. bulgaricus and S. thermophilus can utilize lactose",
          [(0, 32, "Microbe"), (37, 52, "Microbe"), (57, 64, "Consumes"), (65, 72, "Substrate")]),
         ("However, L. delbrueckii subsp. bulgaricus and S. thermophilus cannot naturally use galactose",
          [(9, 41, "Microbe"), (46, 61, "Microbe"), (62, 82, "Doesn't consume"), (83, 92, "Substrate")]),
         ("S. cerevisiae can metabolize galactose through its Leloir pathway producing UDP-glucose",
          [(0, 13, "Microbe"), (14, 28, "Consumes"), (29, 38, "Substrate"), (66, 75, "Produces"), (76, 87, "Metabolite")]),
         ("S. cerevisiae culture was transferred and grown on Malt Extract Agar (MEA) slants at 30 °C",
          [(0, 13, "Microbe"), (42, 47, "Thrives in"), (51, 90, "Condition")]),
         ("L. delbrueckii subsp. bulgaricus and S. thermophilus cultures were regrown on MRS agar slants at 42 °C for 2 days and on M17 agar at 37 °C for 2 days, respectively",
          [(0, 32, "Microbe"), (37, 52, "Microbe"), (67, 74, "Thrives in"), (78, 102, "Condition"), (121, 138, "Condition")]),
         ("30 °C to represent the suboptimal temperature for both L. delbrueckii subsp. bulgaricus and S. thermophilus and to provide the optimal temperature for S. cerevisiae",
          [(0, 5, "Condition"), (127, 146, "Thrives in"), (151, 164, "Microbe")]),
         ("the treatment with S. cerevisiae addition (Figure 2b, Sc-1–Sc-4) showed a significantly lower pH than the milk without any culture (Figure 2b, Sc-0). In both experimental and control groups, increasing the concentration of S. cerevisiae resulted in a lower pH after incubation",
          [(19, 32, "Microbe"), (88, 96, "Causes condition"), (106, 110, "Substrate"), (223, 236, "Microbe"), (237, 259, "Causes condition")]),
         ("indicating that S. cerevisiae could inhibit the growth of L. delbrueckii subsp. bulgaricus and S. thermophilus to some degree",
          [(16, 29, "Microbe"), (36, 54, "Inhibits"), (58, 90, "Microbe"), (95, 110, "Microbe")]),
         ("L. delbrueckii subsp. bulgaricus and S. thermophilus support each other through protocooperation where metabolite exchange occurs",
          [(0, 32, "Microbe"), (37, 52, "Microbe"), (53, 71, "Cocultures with"), (80, 96, "Cocultures with"), (103, 129, "Cocultures with")]),
         ("both L. delbrueckii subsp. bulgaricus and S. thermophilus have ethanol tolerance",
          [(5, 37, "Microbe"), (42, 57, "Microbe"), (63, 70, "Metabolite"), ("Doesn't thrive in")])
     ]}
]

# %%
i = 0
for file in os.listdir(os.getcwd() + "\\fermentation_papers"):
    if i < 5:
        print(i)
        filename = os.fsdecode(file)
        path = Path(os.getcwd() + "\\fermentation_papers\\" + filename)
        try:
            reader = pr(path)
        except:
            continue
        text = ""
        for page in reader.pages:
            text = text + page.extract_text()
        doc = model(text)
        for ent in doc.ents:
            print(ent.text, ent.label_)
        print("end of file", i)
    else:
        break
    i += 1
# Out:
# 0
# 3 CARDINAL
# European Journal of Nutrition ORG
# 2019 DATE
# Erika PERSON
# Hiroshi PERSON
# 1 July 2019 DATE
# Springer-Verlag ORG
# Germany GPE
# Dear Prof Salvatore Chirumbolo WORK_OF_ART
# PhD WORK_OF_ART
# First ORDINAL
# 1 CARDINAL
# quercetin catabo- PERSON
# 2 CARDINAL
# 3 CARDINAL
# QS ORG
# 4 CARDINAL
# gut micro-
# flora PERSON
# quercetin NORP
# 5 CARDINAL
# quercetin PERSON
# Iglewics ORG
# Hoaglin ORG
# Iglewicz GPE
# Hoaglin PRODUCT
# 8 CARDINAL
# 1 CARDINAL
# Kawabata K PERSON
# 2019 DATE
# 24(2):370 CARDINAL
# Henningsson Å ORG
# Björck I, Nyman M ORG
# 2001 DATE
# 45(1):165–168
#  3 MONEY
# Michael M PERSON
# Patil RT PERSON
# 49(3):255–266 CARDINAL
# Trakooncharoenvit A ORG
# Tanaka S PERSON
# al PERSON
# 2019 DATE
# https PERSON
# 4 CARDINAL
# 5 CARDINAL
# Hervert-Hernández D PERSON
# 2011 DATE
# Palafox-Carlos H PERSON
# Ayala GPE
# González-Aguilar PERSON
# 2011 DATE
# 15:76
#  7 DATE
# Flint HJ ORG
# Scott KP PERSON
# Duncan PERSON
# al PERSON
# 2012 DATE
# ...
